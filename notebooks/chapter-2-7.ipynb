# %% [markdown]
# # 패딩
# - 행렬은 길이가 동일해야 하므로 임의로 문장의 길이를 맞춰준다.

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer

preprocessed_sentences = [['barber', 'person'], ['barber', 'good', 'person'], ['barber', 'huge', 'person'], ['knew', 'secret'], ['secret', 'kept', 'huge', 'secret'], ['huge', 'secret'], ['barber', 'kept', 'word'], ['barber', 'kept', 'word'], ['barber', 'kept', 'secret'], ['keeping', 'keeping', 'huge', 'secret', 'driving', 'barber', 'crazy'], ['barber', 'went', 'huge', 'mountain']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(preprocessed_sentences)
encoded = tokenizer.texts_to_sequences(preprocessed_sentences)
print(encoded)
# Out:
# [[1, 5], [1, 8, 5], [1, 3, 5], [9, 2], [2, 4, 3, 2], [3, 2], [1, 4, 6], [1, 4, 6], [1, 4, 2], [7, 7, 3, 2, 10, 1, 11], [1, 12, 3, 13]]

# %%
max_len = max(len(item) for item in encoded)
print('최대 길이: ', max_len)
# Out:
# 최대 길이:  7

# %% [markdown]
# 가상의 단어 PAD(0)를 이용해 길이가 7보다 짧은 문장에는 0을 채워 넣는다.
# - 0을 사용하면 제로 패딩이라고 한다.

# %%
for sentence in encoded:
    while len(sentence) < max_len:
        sentence.append(0)

padded_np = np.array(encoded)
print(padded_np)
# Out:
# [[ 1  5  0  0  0  0  0]
#  [ 1  8  5  0  0  0  0]
#  [ 1  3  5  0  0  0  0]
#  [ 9  2  0  0  0  0  0]
#  [ 2  4  3  2  0  0  0]
#  [ 3  2  0  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  2  0  0  0  0]
#  [ 7  7  3  2 10  1 11]
#  [ 1 12  3 13  0  0  0]]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

encoded = tokenizer.texts_to_sequences(preprocessed_sentences)
padded = pad_sequences(encoded)
print(padded)

# 패딩 방향 지정
post_padded = pad_sequences(encoded, padding = 'post')
print(post_padded)

(post_padded == padded_np).all()
# Out:
# [[ 0  0  0  0  0  1  5]
#  [ 0  0  0  0  1  8  5]
#  [ 0  0  0  0  1  3  5]
#  [ 0  0  0  0  0  9  2]
#  [ 0  0  0  2  4  3  2]
#  [ 0  0  0  0  0  3  2]
#  [ 0  0  0  0  1  4  6]
#  [ 0  0  0  0  1  4  6]
#  [ 0  0  0  0  1  4  2]
#  [ 7  7  3  2 10  1 11]
#  [ 0  0  0  1 12  3 13]]
# [[ 1  5  0  0  0  0  0]
#  [ 1  8  5  0  0  0  0]
#  [ 1  3  5  0  0  0  0]
#  [ 9  2  0  0  0  0  0]
#  [ 2  4  3  2  0  0  0]
#  [ 3  2  0  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  6  0  0  0  0]
#  [ 1  4  2  0  0  0  0]
#  [ 7  7  3  2 10  1 11]
#  [ 1 12  3 13  0  0  0]]
# True

# %%
padded = pad_sequences(encoded, padding='post', maxlen=5) # 최대 길이 제한
padded
# Out:
# array([[ 1,  5,  0,  0,  0],
#        [ 1,  8,  5,  0,  0],
#        [ 1,  3,  5,  0,  0],
#        [ 9,  2,  0,  0,  0],
#        [ 2,  4,  3,  2,  0],
#        [ 3,  2,  0,  0,  0],
#        [ 1,  4,  6,  0,  0],
#        [ 1,  4,  6,  0,  0],
#        [ 1,  4,  2,  0,  0],
#        [ 3,  2, 10,  1, 11],
#        [ 1, 12,  3, 13,  0]], dtype=int32)

# %%
padded = pad_sequences(encoded, padding='post', truncating='post', maxlen=5) # 앞이 아니라 뒤의 단어가 삭제되도록 하고 싶다면 truncating='post'
padded
# Out:
# array([[ 1,  5,  0,  0,  0],
#        [ 1,  8,  5,  0,  0],
#        [ 1,  3,  5,  0,  0],
#        [ 9,  2,  0,  0,  0],
#        [ 2,  4,  3,  2,  0],
#        [ 3,  2,  0,  0,  0],
#        [ 1,  4,  6,  0,  0],
#        [ 1,  4,  6,  0,  0],
#        [ 1,  4,  2,  0,  0],
#        [ 7,  7,  3,  2, 10],
#        [ 1, 12,  3, 13,  0]], dtype=int32)

# %%
last_value = len(tokenizer.word_index) + 1 # 단어 집합의 크기보다 1 큰 숫자를 사용
print(last_value)

padded = pad_sequences(encoded, padding='post', value=last_value) # 패딩 값을 지정
padded
# Out:
# 14
# array([[ 1,  5, 14, 14, 14, 14, 14],
#        [ 1,  8,  5, 14, 14, 14, 14],
#        [ 1,  3,  5, 14, 14, 14, 14],
#        [ 9,  2, 14, 14, 14, 14, 14],
#        [ 2,  4,  3,  2, 14, 14, 14],
#        [ 3,  2, 14, 14, 14, 14, 14],
#        [ 1,  4,  6, 14, 14, 14, 14],
#        [ 1,  4,  6, 14, 14, 14, 14],
#        [ 1,  4,  2, 14, 14, 14, 14],
#        [ 7,  7,  3,  2, 10,  1, 11],
#        [ 1, 12,  3, 13, 14, 14, 14]], dtype=int32)
